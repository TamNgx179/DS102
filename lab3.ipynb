# %%
import numpy as np
import matplotlib.pyplot as plt
from skimage.transform import resize
from skimage.io import imread
import os
import random

# %%
BASE_DIR = 'yalefaces/yalefaces'
person_folders = [
    "person-1",
    "person-2",
    "person-3",
    "person-4",
    "person-5",
    "person-6",
    "person-7",
    "person-8",
    "person-9",
    "person-10",
    "person-11",
    "person-12",
    "person-13",
    "person-14",
    "person-15"
]

# %%
selected_folders = random.choice(person_folders)
plt.figure(figsize = (10,5))
for ith, filename in enumerate(os.listdir(os.path.join(BASE_DIR, selected_folders))):
    image = imread(os.path.join(BASE_DIR, selected_folders, filename))
    print(image.shape)
    image = image.squeeze(0)
    print(image.shape)
    image = resize(image, (64,80), anti_aliasing= True)
    plt.subplot(2, 5, ith+1)
    plt.imshow(image, cmap = "gray")
    plt.axis("off")
    plt.title(filename)
plt.tight_layout()
plt.show()
# Out:
# (1, 243, 320)
# (243, 320)
# (1, 243, 320)
# (243, 320)
# (1, 243, 320)
# (243, 320)
# (1, 243, 320)
# (243, 320)
# (1, 243, 320)
# (243, 320)
# (1, 243, 320)
# (243, 320)
# (1, 243, 320)
# (243, 320)
# (1, 243, 320)
# (243, 320)
# (1, 243, 320)
# (243, 320)
# (1, 243, 320)
# (243, 320)

# %%
data = {}

for person_folder in person_folders:
    person_path = os.path.join(BASE_DIR, person_folder)
    print("Loading folder:", person_path)
    if not os.path.exists(person_path):
        print("Folder not found:", person_path)
        continue  # bỏ qua nếu folder không tồn tại
    for filename in os.listdir(person_path):
        image = imread(os.path.join(person_path, filename))
        image = resize(image, (1, 64, 80), anti_aliasing=True)
        if person_folder not in data:
            data[person_folder] = [image]
        else:
            data[person_folder].append(image)

print(len(data['person-1']))
for person in data:
    #print for know dimensions
    print(data[person][0].shape)
    data[person] =  np.concatenate(data[person],axis=0)
    print(data[person].shape)
    data[person] = data[person].reshape(10,-1)
# Out:
# Loading folder: yalefaces/yalefaces\person-1
# Loading folder: yalefaces/yalefaces\person-2
# Loading folder: yalefaces/yalefaces\person-3
# Loading folder: yalefaces/yalefaces\person-4
# Loading folder: yalefaces/yalefaces\person-5
# Loading folder: yalefaces/yalefaces\person-6
# Loading folder: yalefaces/yalefaces\person-7
# Loading folder: yalefaces/yalefaces\person-8
# Loading folder: yalefaces/yalefaces\person-9
# Loading folder: yalefaces/yalefaces\person-10
# Loading folder: yalefaces/yalefaces\person-11
# Loading folder: yalefaces/yalefaces\person-12
# Loading folder: yalefaces/yalefaces\person-13
# Loading folder: yalefaces/yalefaces\person-14
# Loading folder: yalefaces/yalefaces\person-15
# 10
# (1, 64, 80)
# (10, 64, 80)
# (1, 64, 80)
# (10, 64, 80)
# (1, 64, 80)
# (10, 64, 80)
# (1, 64, 80)
# (10, 64, 80)
# (1, 64, 80)
# (10, 64, 80)
# (1, 64, 80)
# (10, 64, 80)
# (1, 64, 80)
# (10, 64, 80)
# (1, 64, 80)
# (10, 64, 80)
# (1, 64, 80)
# (10, 64, 80)
# (1, 64, 80)
# (10, 64, 80)
# (1, 64, 80)
# (10, 64, 80)
# (1, 64, 80)
# (10, 64, 80)
# (1, 64, 80)
# (10, 64, 80)
# (1, 64, 80)
# (10, 64, 80)
# (1, 64, 80)
# (10, 64, 80)

# %%
def standardlizing(images: np.ndarray) -> np.ndarray:
  images = (images - images.mean()) / images.std()
  images = images.astype(np.float32)
  return images

# %%
class PrincipalComponentAnalysis:
  def __init__(self, d_principle):
      self.d_principle = d_principle

  def fit(self,X:np.ndarray):
    cov = (X.T @ X)
    eigenvalues, eigenvectors = np.linalg.eig(cov)
    max_abs_idx = np.argmax(np.abs(eigenvectors), axis = 0)
    signs = np.sign(eigenvectors[max_abs_idx, range(eigenvectors.shape[0])])
    eigenvectors = eigenvectors*signs[np.newaxis,:]
    eigenvectors = eigenvectors.T

    eigen_pairs = [(np.abs(eigenvalues[i]), eigenvectors[i,:]) for i in range(eigenvectors.shape[0])]

    eigen_pairs.sort(key = lambda pair: pair[0],reverse = True)

    eigenvalues = np.array([value for (value, _) in eigen_pairs])
    eigenvectors = np.array([vector for (_, vector) in eigen_pairs])

    self.principle_values = eigenvalues[:self.d_principle]
    self.W = eigenvectors[:self.d_principle]

  def transform(self, X: np.ndarray) -> np.ndarray:
    X_hat = self.W @ X
    return X_hat

# %%
PCA = PrincipalComponentAnalysis(d_principle=20)
images = []
for person in data:
    images.append(data[person])
images = np.concatenate(images,axis=0)
images = standardlizing(images)
images.shape
# Out:
# (150, 5120)

# %%
PCA.fit(images)
PCA.W
# Out:
# array([[-0.0103703 , -0.01053424, -0.01054564, ..., -0.00139055,
#         -0.0015381 , -0.00127438],
#        [-0.00053991, -0.00116958, -0.00120037, ..., -0.01153713,
#         -0.01075914, -0.01048641],
#        [ 0.00350437,  0.00277395,  0.00242154, ...,  0.0134587 ,
#          0.01285189,  0.0133675 ],
#        ...,
#        [ 0.00198308,  0.00198282,  0.00212671, ..., -0.00604882,
#         -0.00372426, -0.00923365],
#        [ 0.00435989,  0.00384   ,  0.00287027, ..., -0.01025181,
#         -0.00763347, -0.00386044],
#        [ 0.00237033,  0.00281234,  0.00267274, ...,  0.00159889,
#         -0.00242817, -0.00237679]], dtype=float32)

# %%
PCA.W.shape
# Out:
# (20, 5120)

# %%
eigenfaces = PCA.W
eigenfaces = eigenfaces.reshape(20,64,80)
plt.figure(figsize=(10,10))
for ith,eigenface in enumerate(eigenfaces):
    plt.subplot(4,5,ith+1)
    plt.imshow(eigenface,cmap='gray')
    plt.axis('off')
    plt.title(ith+1)
plt.tight_layout()
plt.show()

# %%
mean_faces = {
    person: np.mean(images, axis = 0) for person, images in data.items()
}
x = data.values()
mean_faces
# Out:
# {'person-1': array([0.85419198, 0.85366156, 0.85297667, ..., 0.8303818 , 0.82890742,
#         0.8257649 ]),
#  'person-2': array([0.86544893, 0.88261908, 0.87843098, ..., 0.65963892, 0.71646007,
#         0.68067589]),
#  'person-3': array([0.88537218, 0.8878378 , 0.88600453, ..., 0.78256216, 0.78355067,
#         0.77931486]),
#  'person-4': array([0.87969966, 0.88051314, 0.88361268, ..., 0.72219289, 0.74870393,
#         0.80440018]),
#  'person-5': array([0.87413693, 0.87355455, 0.87875135, ..., 0.43889482, 0.43011748,
#         0.41276937]),
#  'person-6': array([0.86571086, 0.90672724, 0.90728528, ..., 0.75620439, 0.75566818,
#         0.7240958 ]),
#  'person-7': array([0.9108284 , 0.91332992, 0.91410989, ..., 0.84107537, 0.85577481,
#         0.8583894 ]),
#  'person-8': array([0.91467928, 0.91475662, 0.91481714, ..., 0.76983082, 0.77107141,
#         0.7555712 ]),
#  'person-9': array([0.91130895, 0.91350963, 0.91384883, ..., 0.78268471, 0.78721262,
#         0.77856838]),
#  'person-10': array([0.91386501, 0.9130172 , 0.91369885, ..., 0.76091007, 0.74797445,
#         0.76540388]),
#  'person-11': array([0.90639327, 0.90770233, 0.90774824, ..., 0.53462673, 0.50448396,
#         0.45173839]),
#  'person-12': array([0.89759705, 0.9067405 , 0.90748905, ..., 0.56272927, 0.58051377,
#         0.56898003]),
#  'person-13': array([0.91010114, 0.91152437, 0.90667142, ..., 0.67881027, 0.67398636,
#         0.6654516 ]),
#  'person-14': array([0.9028919 , 0.90363767, 0.90600963, ..., 0.87172917, 0.87232531,
#         0.87166588]),
#  'person-15': array([0.87907473, 0.88833609, 0.8950448 , ..., 0.80719322, 0.79216561,
#         0.79912477])}

# %%
plt.figure(figsize=(10,10))
for ith, person in enumerate(mean_faces):
    mean_face = mean_faces[person]
    mean_face = mean_face.reshape(64,80)
    plt.subplot(3,5,ith+1)
    plt.imshow(mean_face,cmap='gray')
    plt.axis('off')
    plt.title(person)
plt.tight_layout()
plt.show()

# %%
projected_mean_faces = {}
for person in mean_faces:
    mean_face = mean_faces[person]
    projected_mean_faces[person] = PCA.transform(mean_face)

# %%
projected_mean_faces['person-1'].shape
# Out:
# (20,)

# %%
labels = []
test_images = []
TEST_DIR = 'yalefaces/yalefaces/test'
for filename in os.listdir(os.path.join(TEST_DIR)):
    person_name = filename.split(".")[0]
    labels.append(person_name)
    image = imread(os.path.join(TEST_DIR,filename))
    image = resize(image,(1,64,80),anti_aliasing=True)
    test_images.append(image)

# %%
test_images = np.concatenate(test_images,axis=0)
test_images.shape
# Out:
# (15, 64, 80)

# %%
labels
# Out:
# ['person-1',
#  'person-10',
#  'person-11',
#  'person-12',
#  'person-13',
#  'person-14',
#  'person-15',
#  'person-2',
#  'person-3',
#  'person-4',
#  'person-5',
#  'person-6',
#  'person-7',
#  'person-8',
#  'person-9']

# %%
def eu_dis(X,Y):
    assert X.shape == Y.shape, f'{X.__str__()} and {Y.__str__()} are miss-shaped'
    return (((X-Y)**2).sum())**0.5

# %%
predictions = {
}
for label, image in zip(labels,test_images):
    image = image.reshape(-1)
    projected_face = PCA.transform(image)
    closest_distance = np.inf
    closest_person = None
    for person in projected_mean_faces:
        mean_face = projected_mean_faces[person]
        distance = eu_dis(mean_face,projected_face)
        if distance < closest_distance:
            closest_distance = distance
            closest_person = person
    predictions[label] = closest_person

# %%
EMs =[]
for label in predictions:
    EMs.append(label==predictions[label])
print(f'Accuracy: {(np.mean(EMs)*100):0.2f}')
# Out:
# Accuracy: 66.67
